# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Text Generation with Neural Networks

# %% [markdown]
# ## Functions for Processing Text
#
# ### Reading in files as a string text

# %%
def read_file(filepath):
    
    with open(filepath, encoding = 'utf8') as f:
        str_text = f.read()
    
    return str_text

# %%
read_file('giant_introduction.txt')
# Out:
# " The ubiquitin/proteasome pathway, responsible for mediating the majority of intracellular proteolysis, plays a crucial role in the regulation of many normal cellular processes, including the cell cycle, differentiation and apoptosis !!!REFs!!!. Defects in proteasome function have been suggested to be involved in the pathogenesis of neurodegenerative diseases, including Alzheimer's disease and Parkinson's disease !!!REF!!!. Proteasome inhibitors have been shown to induce apoptosis in neuronal cells characterized by nuclear fragmentation, loss of mitochondrial membrane potential, cytochrome release and caspase activation !!!REFs!!!. In contrast, proteasome inhibitors lactacystin and AcLLNaI induce apoptotic death in human glioma cells by a mitochondria-independent mechanism !!!REF!!!. In addition, it is uncertain whether the cytotoxicity of MG132 is mediated by elevation of the intracellular Ca2+ levels !!!REFs!!!. Disruption of intracellular calcium homeostasis and defects in mitochondrial function mediate neuronal cell death !!!REFs!!!. Elevation of intracellular Ca2+ levels leads to the production of reactive oxygen species (ROS) and nitrogen species !!!REF!!!. Ca2+ overload may excessively activate Ca2+/calmodulin-dependent pathways and leads to irreversible cell damage !!!REF!!!. Calmodulin antagonists such as W-7 and trifluoperazine inhibit cell death due to 1-methyl-4-phenylpyridinium (MPP+) or veratridine-induced depolarization !!!REFs!!!. Trifluoperazine as an inhibitor of the mitochondrial permeability transition is demonstrated to reduce oxidative stress-induced cell death by suppressing the cytochrome release and mitochondrial depolarization !!!REFs!!!. Meanwhile, phenothiazines, including trifluoperazine, show a strong cytotoxicity and antiproliferative activity against neuronal cells and leukemic cells !!!REFs!!!. MG132, which effectively blocks the proteolytic activity of 26S proteasome complex, causes apoptotic cell death through formation of ROS !!!REFs!!!. Although calmodulin antagonist such as trifluoperazine is demonstrated to reduce oxidative cell injury, the effect on mitochondrial damage and apoptotic cell death due to MG132 has not been elucidated. The aim of the present study was to explore the effect of calmodulin antagonists (trifluoperazine, W-7 and calmidazolium) on the MG132-induced mitochondrial dysfunction and cell death in PC12 cells. This study examined the effect of calmodulin antagonists on mitochondrial damage and subsequent cytochrome release, changes in intracellular Ca2+ levels, formation of ROS and cellular GSH contents.                             Of all sleep disorders, insomnia is the most prevalent among adults. The estimated population prevalence of difficulties in initiating and maintaining sleep is about 30%, while the prevalence of frequent, severe insomnia is reported as being closer to 10–15% (e.g. !!!REF!!!). Different estimates of the prevalence of insomnia reflect the fact that the difficulties in initiating or maintaining sleep have been variously regarded as a complaint, a disorder, a symptom, a disease and a finding !!!REF!!!. At present, most researchers consider the duration and severity criteria proposed by the DSM-IV !!!REF!!! and by the ICSD-R !!!REF!!! classifications as the “standard” for the definition of insomnia. Both classifications assign a crucial role to the subjective complaint of insufficient or inadequate sleep. Current clinical guidelines have given less emphasize to the relevance of objective data (poligraphic recordings) in the diagnosis of insomnia which are now primarily based on what the patients report !!!REFs!!!. Self-report questionnaires have for a long time been the easiest and most widely used method of collecting data for epidemiological studies on insomnia and on other sleep impairments. Questionnaires and structured interviews could be used for screening purposes within the early stage of clinical assessment !!!REF!!!. Unfortunately, howev ...

# %% [markdown]
# ### Tokenize and Clean Text

# %%
import spacy
nlp = spacy.load('en',disable=['parser', 'tagger','ner'])

nlp.max_length = 1398623

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n !!!refs!!! !!! ref!!! !!!ref !!! refs refs!!! !!!refs !!!REF!!! \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
d = read_file('giant_introduction.txt')
tokens = separate_punc(d)

# %%
tokens
# Out:
# ['the',
#  'ubiquitin',
#  'proteasome',
#  'pathway',
#  'responsible',
#  'for',
#  'mediating',
#  'the',
#  'majority',
#  'of',
#  'intracellular',
#  'proteolysis',
#  'plays',
#  'a',
#  'crucial',
#  'role',
#  'in',
#  'the',
#  'regulation',
#  'of',
#  'many',
#  'normal',
#  'cellular',
#  'processes',
#  'including',
#  'the',
#  'cell',
#  'cycle',
#  'differentiation',
#  'and',
#  'apoptosis',
#  'refs!!!.',
#  'defects',
#  'in',
#  'proteasome',
#  'function',
#  'have',
#  'been',
#  'suggested',
#  'to',
#  'be',
#  'involved',
#  'in',
#  'the',
#  'pathogenesis',
#  'of',
#  'neurodegenerative',
#  'diseases',
#  'including',
#  'alzheimer',
#  "'s",
#  'disease',
#  'and',
#  'parkinson',
#  "'s",
#  'disease',
#  'ref!!!.',
#  'proteasome',
#  'inhibitors',
#  'have',
#  'been',
#  'shown',
#  'to',
#  'induce',
#  'apoptosis',
#  'in',
#  'neuronal',
#  'cells',
#  'characterized',
#  'by',
#  'nuclear',
#  'fragmentation',
#  'loss',
#  'of',
#  'mitochondrial',
#  'membrane',
#  'potential',
#  'cytochrome',
#  'release',
#  'and',
#  'caspase',
#  'activation',
#  'refs!!!.',
#  'in',
#  'contrast',
#  'proteasome',
#  'inhibitors',
#  'lactacystin',
#  'and',
#  'acllnai',
#  'induce',
#  'apoptotic',
#  'death',
#  'in',
#  'human',
#  'glioma',
#  'cells',
#  'by',
#  'a',
#  'mitochondria',
#  'independent',
#  'mechanism',
#  'ref!!!.',
#  'in',
#  'addition',
#  'it',
#  'is',
#  'uncertain',
#  'whether',
#  'the',
#  'cytotoxicity',
#  'of',
#  'mg132',
#  'is',
#  'mediated',
#  'by',
#  'elevation',
#  'of',
#  'the',
#  'intracellular',
#  'ca2',
#  'levels',
#  'refs!!!.',
#  'disruption',
#  'of',
#  'intracellular',
#  'calcium',
#  'homeostasis',
#  'and',
#  'defects',
#  'in',
#  'mitochondrial',
#  'function',
#  'mediate',
#  'neuronal',
#  'cell',
#  'death',
#  'refs!!!.',
#  'elevation',
#  'of',
#  'intracellular',
#  'ca2',
#  'levels',
#  'leads',
#  'to',
#  'the',
#  'production',
#  'of',
#  'reactive',
#  'oxygen',
#  'species',
#  'ros',
#  'and',
#  'nitrogen',
#  'species',
#  'ref!!!.',
#  'ca2',
#  'overload',
#  'may',
#  'excessively',
#  'activate',
#  'ca2+/calmodulin',
#  'dependent',
#  'pathways',
#  'and',
#  'leads',
#  'to',
#  'irreversible',
#  'cell',
#  'damage',
#  'ref!!!.',
#  'calmodulin',
#  'antagonists',
#  'such',
#  'as',
#  'w-7',
#  'and',
#  'trifluoperazine',
#  'inhibit',
#  'cell',
#  'death',
#  'due',
#  'to',
#  '1-methyl-4-phenylpyridinium',
#  'mpp+',
#  'or',
#  'veratridine',
#  'induced',
#  'depolarization',
#  'refs!!!.',
#  'trifluoperazine',
#  'as',
#  'an',
#  'inhibitor',
#  'of',
#  'the',
#  'mitochondrial',
#  'permeability',
#  'transition',
#  'is',
#  'demonstrated',
#  'to',
#  'reduce',
#  'oxidative',
#  'stress',
#  'induced',
#  'cell',
#  'death',
#  'by',
#  'suppressing',
#  'the',
#  'cytochrome',
#  'release',
#  'and',
#  'mitochondrial',
#  'depolarization',
#  'refs!!!.',
#  'meanwhile',
#  'phenothiazines',
#  'including',
#  'trifluoperazine',
#  'show',
#  'a',
#  'strong',
#  'cytotoxicity',
#  'and',
#  'antiproliferative',
#  'activity',
#  'against',
#  'neuronal',
#  'cells',
#  'and',
#  'leukemic',
#  'cells',
#  'refs!!!.',
#  'mg132',
#  'which',
#  'effectively',
#  'blocks',
#  'the',
#  'proteolytic',
#  'activity',
#  'of',
#  '26s',
#  'proteasome',
#  'complex',
#  'causes',
#  'apoptotic',
#  'cell',
#  'death',
#  'through',
#  'formation',
#  'of',
#  'ros',
#  'refs!!!.',
#  'although',
#  'calmodulin',
#  'antagonist',
#  'such',
#  'as',
#  'trifluoperazine',
#  'is',
#  'demonstrated',
#  'to',
#  'reduce',
#  'oxidative',
#  'cell',
#  'injury',
#  'the',
#  'effect',
#  'on',
#  'mitochondrial',
#  'damage',
#  'and',
#  'apoptotic',
#  'cell',
#  'death',
#  'due',
#  'to',
#  'mg132',
#  'has',
#  'not',
#  'been',
#  'elucidated',
#  'the',
#  'aim',
#  'of',
#  'the',
#  'present',
#  'study',
#  'was',
#  'to',
#  'explore',
#  'the',
#  'effect',
#  'of',
#  'calmodulin',
#  'antagonists',
#  'trifluoperazine',
#  'w-7',
#  'and',
#  'calmidazolium',
#  'on',
#  'the',
#  'mg132-induced',
#  'mitochondrial',
#  'dysfunction',
#  'and',
#  'cell',
#  'death',
#  'in',
#  'pc12',
#  'cells',
#  'this',
#  'study',
#  'examined',
#  'the',
#  'effect',
#  'of',
#  'calmodulin',
#  'antagonists',
#  'on',
#  'mitochondrial',
#  'damage',
#  'and',
#  'subsequent',
#  'cytochrome',
#  'release',
#  'changes',
#  'in',
#  'intracellular',
#  'ca2',
#  'levels',
#  'formation',
#  'of',
#  'ros',
#  'and',
#  'cellular',
#  'gsh',
#  'contents',
#  '                            ',
#  'of',
#  'all',
#  'sleep',
#  'disorders',
#  'insomnia',
#  'is',
#  'the',
#  'most',
#  'prevalent',
#  'among',
#  'adults',
#  'the',
#  'estimated',
#  'population',
#  'prevalence',
#  'of',
#  'difficulties',
#  'in',
#  'initiating',
#  'and',
#  'maintaining',
#  'sleep',
#  'is',
#  'about',
#  '30',
#  'while',
#  'the',
#  'prevalence',
#  'of',
#  'frequent',
#  'severe',
#  'insomnia',
#  'is',
#  'reported',
#  'as',
#  'being',
#  'closer',
#  'to',
#  '10–15',
#  'e.g.',
#  'different',
#  'estimates',
#  'of',
#  'the',
#  'prevalence',
#  'of',
#  'insomnia',
#  'reflect',
#  'the',
#  'fact',
#  'that',
#  'the',
#  'difficulties',
#  'in',
#  'initiating',
#  'or',
#  'maintaining',
#  'sleep',
#  'have',
#  'been',
#  'variously',
#  'regarded',
#  'as',
#  'a',
#  'complaint',
#  'a',
#  'disorder',
#  'a',
#  'symptom',
#  'a',
#  'disease',
#  'and',
#  'a',
#  'finding',
#  'ref!!!.',
#  'at',
#  'present',
#  'most',
#  'researchers',
#  'consider',
#  'the',
#  'duration',
#  'and',
#  'severity',
#  'criteria',
#  'proposed',
#  'by',
#  'the',
#  'dsm',
#  'iv',
#  'and',
#  'by',
#  'the',
#  'icsd',
#  'classifications',
#  'as',
#  'the',
#  '“',
#  'standard',
#  '”',
#  'for',
#  'the',
#  'definition',
#  'of',
#  'insomnia',
#  'both',
#  'classifications',
#  'assign',
#  'a',
#  'crucial',
#  'role',
#  'to',
#  'the',
#  'subjective',
#  'complaint',
#  'of',
#  'insufficient',
#  'or',
#  'inadequate',
#  'sleep',
#  'current',
#  'clinical',
#  'guidelines',
#  'have',
#  'given',
#  'less',
#  'emphasize',
#  'to',
#  'the',
#  'relevance',
#  'of',
#  'objective',
#  'data',
#  'poligraphic',
#  'recordings',
#  'in',
#  'the',
#  'diagnosis',
#  'of',
#  'insomnia',
#  'which',
#  'are',
#  'now',
#  'primarily',
#  'based',
#  'on',
#  'what',
#  'the',
#  'patients',
#  'report',
#  'refs!!!.',
#  'self',
#  'report',
#  'questionnaires',
#  'have',
#  'for',
#  'a',
#  'long',
#  'time',
#  'been',
#  'the',
#  'easiest',
#  'and',
#  'most',
#  'widely',
#  'used',
#  'method',
#  'of',
#  'collecting',
#  'data',
#  'for',
#  'epidemiological',
#  'studies',
#  'on',
#  'insomnia',
#  'and',
#  'on',
#  'other',
#  'sleep',
#  'impairments',
#  'questionnaires',
#  'and',
#  'structured',
#  'interviews',
#  'could',
#  'be',
#  'used',
#  'for',
#  'screening',
#  'purposes',
#  'within',
#  'the',
#  'early',
#  'stage',
#  'of',
#  'clinical',
#  'assessment',
#  'ref!!!.',
#  'unfortunately',
#  'however',
#  'most',
#  'paper',
#  'and',
#  'pencil',
#  'instruments',
#  'are',
#  'either',
#  'very',
#  'long',
#  'or',
#  'do',
#  'not',
#  'include',
#  'all',
#  'the',
#  'questions',
#  'necessary',
#  'for',
#  'the',
#  'assessment',
#  'of',
#  'the',
#  'severity',
#  'of',
#  'the',
#  'complaint',
#  'according',
#  'to',
#  'current',
#  'standards',
#  'in',
#  'order',
#  'to',
#  'obtain',
#  'an',
#  'adequate',
#  'recognition',
#  'of',
#  'insomnia',
#  'an',
#  'interview',
#  'or',
#  'a',
#  'questionnaire',
#  'should',
#  'consider',
#  'the',
#  'main',
#  'aspects',
#  'which',
#  'characterize',
#  'the',
#  'disorder',
#  'according',
#  'to',
#  'both',
#  'the',
#  'dsm',
#  'iv',
#  'and',
#  'icsd',
#  'diagnostic',
#  'systems',
#  'and',
#  'to',
#  'recent',
#  'consensus',
#  'reports',
#  'ref!!!.',
#  'these',
#  'aspects',
#  'include',
#  'symptoms',
#  'intensity',
#  'frequency',
#  'and',
#  'duration',
#  'of',
#  'sleep',
#  'difficulties',
#  'as',
#  'well',
#  'as',
#  'their',
#  'impact',
#  'on',
#  'daytime',
#  'functioning',
#  'with',
#  'regards',
#  'to',
#  'the',
#  'intensity',
#  'of',
#  'symptoms',
#  'insomnia',
#  'is',
#  'defined',
#  'by',
#  'a',
#  'sleep',
#  'onset',
#  'latency',
#  'of',
#  'more',
#  'than',
#  '30min',
#  'and/or',
#  'by',
#  'awakenings',
#  'after',
#  'sleep',
#  'onset',
#  'of',
#  'more',
#  'than',
#  '30min',
#  'and/or',
#  'by',
#  'an',
#  'early',
#  'morning',
#  'awakening',
#  'ref!!!.',
#  'according',
#  'to',
#  'the',
#  'dsm',
#  'iv',
#  'and',
#  'the',
#  'icsd',
#  'the',
#  'co',
#  'occurrence',
#  'of',
#  'three',
#  'criteria',
#  'is',
#  'required',
#  'in',
#  'order',
#  'to',
#  'establish',
#  'the',
#  'presence',
#  'of',
#  'a',
#  'problem',
#  'of',
#  'insomnia',
#  'which',
#  'is',
#  'both',
#  'so',
#  'severe',
#  'and',
#  'chronic',
#  'to',
#  'be',
#  'considered',
#  'relevant',
#  'from',
#  'a',
#  'clinical',
#  'point',
#  'of',
#  'view',
#  'these',
#  'are',
#  'the',
#  'following',
#  '1',
#  'the',
#  'sleep',
#  'disturbance',
#  'must',
#  'be',
#  'reported',
#  'as',
#  'present',
#  'three',
#  'or',
#  'more',
#  'nights',
#  'per',
#  'week',
#  '2',
#  'the',
#  'subject',
#  'must',
#  'refer',
#  'to',
#  'a',
#  'complaint',
#  'of',
#  'insomnia',
#  'that',
#  'lasts',
#  'for',
#  'more',
#  'than',
#  '1',
#  'month',
#  '3',
#  'the',
#  'subject',
#  'must',
#  'state',
#  'that',
#  'the',
#  'sleep',
#  'disturbance',
#  'causes',
#  'significant',
#  'impairment',
#  'in',
#  'her',
#  'his',
#  'social',
#  'occupational',
#  'or',
#  'cognitive',
#  'daytime',
#  'functioning',
#  'most',
#  'of',
#  'the',
#  'epidemiological',
#  'surveys',
#  'that',
#  'have',
#  'so',
#  'far',
#  'been',
#  'made',
#  'have',
#  'not',
#  'used',
#  'questionnaires',
#  'based',
#  'on',
#  'the',
#  'aforesaid',
#  'criteria',
#  'but',
#  'have',
#  'focused',
#  'on',
#  'a',
#  'few',
#  'general',
#  'questions',
#  'on',
#  'habitual',
#  'sleep',
#  'quality',
#  'and',
#  'on',
#  'the',
#  'type',
#  'of',
#  'sleep',
#  'disturbance',
#  'refs!!!.',
#  'more',
#  'recently',
#  'standard',
#  'criteria',
#  'have',
#  'been',
#  'used',
#  'in',
#  'studies',
#  'based',
#  'on',
#  'computer',
#  'aided',
#  'telephone',
#  'interviews',
#  '—',
#  'cati',
#  'refs!!!.',
#  'however',
#  'it',
#  'is',
#  'difficult',
#  'to',
#  'reconcile',
#  'the',
#  'systematic',
#  'scientific',
#  'soundness',
#  'of',
#  'cati',
#  'methods',
#  'with',
#  'the',
#  'necessities',
#  'of',
#  'screening',
#  'and',
#  'clinical',
#  'settings',
#  'in',
#  'which',
#  'for',
#  'practical',
#  'reasons',
#  'the',
#  'use',
#  'of',
#  'brief',
#  'paper',
#  'and',
#  'pencil',
#  'questionnaires',
#  'is',
#  'often',
#  'recommended',
#  'different',
#  'self',
#  'reported',
#  'measures',
#  'of',
#  'sleep',
#  'disturbances',
#  'have',
#  'been',
#  'used',
#  'in',
#  'screenings',
#  'and',
#  'in',
#  'clinical',
#  'settings',
#  'among',
#  'the',
#  'most',
#  'widely',
#  'used',
#  'some',
#  'focus',
#  'specifically',
#  'on',
#  'the',
#  'daytime',
#  'consequences',
#  'of',
#  'insomnia',
#  'the',
#  'sleep',
#  'impairment',
#  'index',
#  'while',
#  'others',
#  'focus',
#  'on',
#  'the',
#  'cognitive',
#  'aspects',
#  'of',
#  'the',
#  'disorder',
#  'dysfunctional',
#  'beliefs',
#  'and',
#  'attitudes',
#  'about',
#  'sleep',
#  'scale',
#  'sleep',
#  'disturbance',
#  'questionnaire',
#  'most',
#  'questionnaires',
#  'assess',
#  'insomnia',
#  'symptoms',
#  'and',
#  'sleep',
#  'dissatisfaction',
#  'e.g.',
#  'sleep',
#  'disorders',
#  'questionnaire',
#  'sdq',
#  'pittsburgh',
#  'sleep',
#  'quality',
#  'index',
#  'psqi',
#  'but',
#  'they',
#  'do',
#  'not',
#  'ask',
#  'for',
#  'a',
#  'subjective',
#  'evaluation',
#  'of',
#  'insomnia',
#  'according',
#  'to',
#  'the',
#  'criteria',
#  'considered',
#  'by',
#  'the',
#  'dsm',
#  'iv',
#  'or',
#  'icsd',
#  'r.',
#  'the',
#  'pittsburgh',
#  'sleep',
#  'quality',
#  'index',
#  'is',
#  'among',
#  'the',
#  'most',
#  'widely',
#  'used',
#  'and',
#  'validated',
#  'sleep',
#  'disorder',
#  'questionnaires',
#  'the',
#  'psqi',
#  'is',
#  'not',
#  'designed',
#  'to',
#  'define',
#  'the',
#  'presence',
#  'of',
#  'insomnia',
#  'but',
#  'to',
#  'assess',
#  'different',
#  'features',
#  'of',
#  'sleep',
#  'quality',
#  'the',
#  'psychometric',
#  'proprieties',
#  'of',
#  'the',
#  'psqi',
#  'have',
#  'been',
#  'extensively',
#  ...]

# %%
len(tokens)
# Out:
# 159900

# %%
4431/25
# Out:
# 177.24

# %% [markdown]
# ## Create Sequences of Tokens

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):
    
    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]
    
    # Add to list of sequences
    text_sequences.append(seq)

# %%
' '.join(text_sequences[0])
# Out:
# 'the ubiquitin proteasome pathway responsible for mediating the majority of intracellular proteolysis plays a crucial role in the regulation of many normal cellular processes including the'

# %%
' '.join(text_sequences[1])
# Out:
# 'ubiquitin proteasome pathway responsible for mediating the majority of intracellular proteolysis plays a crucial role in the regulation of many normal cellular processes including the cell'

# %%
' '.join(text_sequences[2])
# Out:
# 'proteasome pathway responsible for mediating the majority of intracellular proteolysis plays a crucial role in the regulation of many normal cellular processes including the cell cycle'

# %%
len(text_sequences)
# Out:
# 159874

# %% [markdown]
# # Keras

# %% [markdown]
# ### Keras Tokenization

# %%
from keras.preprocessing.text import Tokenizer

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [1,
#  5020,
#  2162,
#  496,
#  606,
#  13,
#  821,
#  1,
#  1638,
#  2,
#  605,
#  4177,
#  514,
#  6,
#  820,
#  56,
#  3,
#  1,
#  160,
#  2,
#  170,
#  162,
#  310,
#  175,
#  87,
#  1]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'in',
#  4: 'and',
#  5: 'to',
#  6: 'a',
#  7: 'is',
#  8: 'that',
#  9: 'ref!!!.',
#  10: 'refs!!!.',
#  11: 'by',
#  12: 'with',
#  13: 'for',
#  14: 'as',
#  15: 'are',
#  16: 'on',
#  17: 'been',
#  18: 'be',
#  19: 'this',
#  20: 'have',
#  21: 'or',
#  22: 'has',
#  23: 'an',
#  24: 'brain',
#  25: 'was',
#  26: 'refs',
#  27: 'which',
#  28: 'these',
#  29: 'from',
#  30: 'it',
#  31: 'we',
#  32: 'neurons',
#  33: 'also',
#  34: 'studies',
#  35: 'rats',
#  36: 'were',
#  37: 'receptors',
#  38: 'effects',
#  39: 'study',
#  40: 'not',
#  41: 'activity',
#  42: 'receptor',
#  43: 'may',
#  44: 'can',
#  45: 'such',
#  46: 'during',
#  47: 'induced',
#  48: 'cells',
#  49: 'sleep',
#  50: 'between',
#  51: 'at',
#  52: 'expression',
#  53: 'however',
#  54: 'both',
#  55: 'system',
#  56: 'role',
#  57: 'changes',
#  58: 'cell',
#  59: 'effect',
#  60: 'other',
#  61: 'task',
#  62: 'different',
#  63: 'present',
#  64: 'but',
#  65: 'neuronal',
#  66: 'response',
#  67: 'stress',
#  68: 'after',
#  69: 'activation',
#  70: 'shown',
#  71: 'used',
#  72: 'no',
#  73: 'memory',
#  74: 'reported',
#  75: 'related',
#  76: 'stimulation',
#  77: 'well',
#  78: 'some',
#  79: 'one',
#  80: 'more',
#  81: 'several',
#  82: 'cortex',
#  83: 'central',
#  84: 'associated',
#  85: 'two',
#  86: 'animals',
#  87: 'including',
#  88: 'their',
#  89: 'rat',
#  90: 'involved',
#  91: 'learning',
#  92: 'there',
#  93: 'when',
#  94: 'found',
#  95: 'than',
#  96: 'neural',
#  97: 'non',
#  98: 'patients',
#  99: 'levels',
#  100: 'increase',
#  101: 'most',
#  102: 'nucleus',
#  103: 'protein',
#  104: 'its',
#  105: 'al',
#  106: 'important',
#  107: 'glutamate',
#  108: 'disease',
#  109: 'et',
#  110: 'responses',
#  111: 'only',
#  112: 'information',
#  113: 'hippocampal',
#  114: '“',
#  115: 'our',
#  116: '”',
#  117: 'high',
#  118: '–',
#  119: 'regions',
#  120: 'nmda',
#  121: 'release',
#  122: 'they',
#  123: 'hippocampus',
#  124: 'whether',
#  125: 'administration',
#  126: 'model',
#  127: 'known',
#  128: 'using',
#  129: 'mice',
#  130: 'into',
#  131: 'specific',
#  132: 'increased',
#  133: 'function',
#  134: 'motor',
#  135: 'observed',
#  136: 'thus',
#  137: 'cognitive',
#  138: 'evidence',
#  139: 'demonstrated',
#  140: 'spatial',
#  141: 'cortical',
#  142: 'within',
#  143: 'therefore',
#  144: 'results',
#  145: 'synaptic',
#  146: 'control',
#  147: 'performance',
#  148: 'long',
#  149: 'could',
#  150: 'areas',
#  151: 'although',
#  152: 'development',
#  153: 'all',
#  154: 'while',
#  155: 'functional',
#  156: 'behavior',
#  157: 'following',
#  158: 'lesions',
#  159: 'functions',
#  160: 'regulation',
#  161: 'treatment',
#  162: 'normal',
#  163: 'e.g.',
#  164: 'stimulus',
#  165: 'dopamine',
#  166: 'would',
#  167: 'since',
#  168: 'human',
#  169: 'number',
#  170: 'many',
#  171: 'c',
#  172: 'gene',
#  173: 'subjects',
#  174: 'mechanisms',
#  175: 'processes',
#  176: 'behavioral',
#  177: 'experimental',
#  178: 'tasks',
#  179: 'time',
#  180: 'chronic',
#  181: 'area',
#  182: 'blood',
#  183: 'data',
#  184: 'type',
#  185: 'age',
#  186: 'stimuli',
#  187: 'addition',
#  188: 'previous',
#  189: 'first',
#  190: 'level',
#  191: 'if',
#  192: 'exposure',
#  193: 'da',
#  194: 'zinc',
#  195: 'test',
#  196: 'visual',
#  197: "'s",
#  198: 'nervous',
#  199: 'cholinergic',
#  200: 'through',
#  201: 'similar',
#  202: 'processing',
#  203: 'opioid',
#  204: 'death',
#  205: 'show',
#  206: 'action',
#  207: 'because',
#  208: 'acid',
#  209: 'recently',
#  210: 'adult',
#  211: 'factors',
#  212: 'region',
#  213: 'cerebral',
#  214: 'female',
#  215: 'drugs',
#  216: 'based',
#  217: 'recent',
#  218: 'use',
#  219: 'conditions',
#  220: 'pain',
#  221: 'damage',
#  222: 'differences',
#  223: 'term',
#  224: 'suggested',
#  225: 'significant',
#  226: 'same',
#  227: 'body',
#  228: 'mediated',
#  229: 'various',
#  230: 'disorders',
#  231: 'see',
#  232: 'antagonist',
#  233: 'about',
#  234: 'binding',
#  235: 'cns',
#  236: 'physiological',
#  237: 'low',
#  238: 'moreover',
#  239: 'systems',
#  240: 'cues',
#  241: 'furthermore',
#  242: 'play',
#  243: 'animal',
#  244: 'male',
#  245: 'amygdala',
#  246: 'order',
#  247: 'mrna',
#  248: 'rem',
#  249: 'induce',
#  250: 'example',
#  251: 'showed',
#  252: 'possible',
#  253: 'dependent',
#  254: 'fos',
#  255: 'pattern',
#  256: 'hypothalamus',
#  257: 'under',
#  258: 'major',
#  259: 'over',
#  260: 'spinal',
#  261: 'primary',
#  262: 'might',
#  263: 'suggest',
#  264: 'examined',
#  265: 'hypothesis',
#  266: 'three',
#  267: 'like',
#  268: 'drug',
#  269: 'compared',
#  270: '1',
#  271: 'expressed',
#  272: 'ad',
#  273: 'peripheral',
#  274: 'd',
#  275: 'inhibition',
#  276: 'clinical',
#  277: 'further',
#  278: 'those',
#  279: 'group',
#  280: 'prefrontal',
#  281: 'injury',
#  282: 'investigated',
#  283: 'analysis',
#  284: 'movement',
#  285: 'formation',
#  286: 'among',
#  287: 'agonist',
#  288: 'due',
#  289: 'ltp',
#  290: 'fibers',
#  291: 'increases',
#  292: 'proteins',
#  293: 'vivo',
#  294: 'injection',
#  295: 'dopaminergic',
#  296: 'acute',
#  297: 'eeg',
#  298: 'antagonists',
#  299: 'production',
#  300: 'l',
#  301: 'movements',
#  302: 'frontal',
#  303: 'period',
#  304: 'either',
#  305: 'frequency',
#  306: 'presence',
#  307: 'humans',
#  308: 'produced',
#  309: 'findings',
#  310: 'cellular',
#  311: 'characterized',
#  312: 'early',
#  313: 'water',
#  314: 'selective',
#  315: 'ability',
#  316: 'loss',
#  317: 'species',
#  318: 'symptoms',
#  319: 'tissue',
#  320: 'structures',
#  321: 'particular',
#  322: 'ii',
#  323: 'studied',
#  324: 'behavioural',
#  325: 'complex',
#  326: 'described',
#  327: 'potential',
#  328: 'secretion',
#  329: 'single',
#  330: 'disorder',
#  331: 'hypothalamic',
#  332: 'previously',
#  333: 'growth',
#  334: 'properties',
#  335: 'days',
#  336: 'pd',
#  337: 'ethanol',
#  338: 'ca2',
#  339: 'aim',
#  340: 'result',
#  341: 'nicotine',
#  342: 'gender',
#  343: 'and/or',
#  344: 'impairment',
#  345: 'via',
#  346: 'basal',
#  347: 'phase',
#  348: 'dorsal',
#  349: 'models',
#  350: 'process',
#  351: 'alterations',
#  352: 'factor',
#  353: 'vestibular',
#  354: 'very',
#  355: '2',
#  356: 'lateral',
#  357: 'each',
#  358: 'determine',
#  359: 'parallel',
#  360: 'excitatory',
#  361: 'nerve',
#  362: 'actions',
#  363: 'theta',
#  364: 'pathways',
#  365: 'considered',
#  366: 'state',
#  367: 'sensitive',
#  368: 'lesion',
#  369: 'i.e.',
#  370: 'inhibitory',
#  371: 'mechanism',
#  372: 'groups',
#  373: 'medial',
#  374: 'nuclei',
#  375: 'types',
#  376: 'place',
#  377: 'impaired',
#  378: 'current',
#  379: 'less',
#  380: 'widely',
#  381: 'large',
#  382: 'reduced',
#  383: 'whereas',
#  384: 'components',
#  385: 'activated',
#  386: 'deprivation',
#  387: '’s',
#  388: 'day',
#  389: 'acquisition',
#  390: 'new',
#  391: 'had',
#  392: 'measured',
#  393: 'contrast',
#  394: 'often',
#  395: 'reduction',
#  396: 'performed',
#  397: 'will',
#  398: 'evoked',
#  399: 'hormone',
#  400: 'transmission',
#  401: 'relationship',
#  402: 'object',
#  403: 'maternal',
#  404: 'proposed',
#  405: 'anterior',
#  406: 'part',
#  407: 'amino',
#  408: 'higher',
#  409: 'small',
#  410: 'involvement',
#  411: 'postural',
#  412: 'even',
#  413: 'temporal',
#  414: 'reports',
#  415: 'form',
#  416: 'vitro',
#  417: 'synthesis',
#  418: 'knowledge',
#  419: 'decrease',
#  420: 'inflammatory',
#  421: 'lead',
#  422: 'post',
#  423: 'variety',
#  424: 'influence',
#  425: 'seizures',
#  426: 'sensory',
#  427: 'significantly',
#  428: 'produce',
#  429: 'aging',
#  430: 'maze',
#  431: 'pressure',
#  432: 'apoptosis',
#  433: 'especially',
#  434: 'events',
#  435: 'distribution',
#  436: 'platform',
#  437: 'where',
#  438: 'gaba',
#  439: 'experiments',
#  440: 'mouse',
#  441: 'vitamin',
#  442: 'oxidative',
#  443: 'given',
#  444: 'then',
#  445: 'identified',
#  446: 'support',
#  447: 'morphine',
#  448: 'striatum',
#  449: 'suggests',
#  450: 'neurotransmitters',
#  451: 'neurotransmitter',
#  452: 'novel',
#  453: 'd3',
#  454: 'so',
#  455: 'tissues',
#  456: 'provide',
#  457: 'any',
#  458: 'agonists',
#  459: 'without',
#  460: 'membrane',
#  461: 'being',
#  462: 'onset',
#  463: 'research',
#  464: 'indicate',
#  465: 'critical',
#  466: 'short',
#  467: 'affected',
#  468: 'pyramidal',
#  469: 'channels',
#  470: 'appears',
#  471: 'plasma',
#  472: 'nos',
#  473: 'dose',
#  474: 'ms',
#  475: 'young',
#  476: 'endogenous',
#  477: 'genes',
#  478: 'alpha',
#  479: 'do',
#  480: 'according',
#  481: 'rodents',
#  482: 'review',
#  483: 'pharmacological',
#  484: 'altered',
#  485: 'sexual',
#  486: 'av3v',
#  487: 'leads',
#  488: 'method',
#  489: 'temperature',
#  490: 'essential',
#  491: 'pituitary',
#  492: 'structure',
#  493: 'electrical',
#  494: 'objects',
#  495: 'length',
#  496: 'pathway',
#  497: 'differentiation',
#  498: 'alzheimer',
#  499: 'thought',
#  500: 'decreased',
#  501: 'avp',
#  502: 'metabolism',
#  503: 'up',
#  504: 'directly',
#  505: 'direct',
#  506: 'plasticity',
#  507: 'occur',
#  508: 'suggesting',
#  509: 'examine',
#  510: 'years',
#  511: 'change',
#  512: 'rate',
#  513: 'epilepsy',
#  514: 'plays',
#  515: 'against',
#  516: 'should',
#  517: 'app',
#  518: 'peptide',
#  519: 'survival',
#  520: 'light',
#  521: 'cerebellum',
#  522: 'likely',
#  523: 'does',
#  524: 'administered',
#  525: 'particularly',
#  526: 'ventral',
#  527: 'respectively',
#  528: 'located',
#  529: 'concentration',
#  530: 'tested',
#  531: 'before',
#  532: 'fiber',
#  533: 'posterior',
#  534: 'behaviour',
#  535: 'ka',
#  536: 'general',
#  537: 'lh',
#  538: 'hand',
#  539: 'investigate',
#  540: 'highly',
#  541: 'derived',
#  542: 'approach',
#  543: 'another',
#  544: 'rather',
#  545: 'induction',
#  546: 'strategy',
#  547: 'semantic',
#  548: '3',
#  549: 'astrocytes',
#  550: 't',
#  551: 'available',
#  552: 'flow',
#  553: 'signals',
#  554: 'afferents',
#  555: 'indeed',
#  556: 'terminals',
#  557: 'mainly',
#  558: 'deficits',
#  559: 'requires',
#  560: 'applied',
#  561: 'cord',
#  562: 'orientation',
#  563: 'few',
#  564: 'relatively',
#  565: 'density',
#  566: 'females',
#  567: 'basis',
#  568: 'oxide',
#  569: 'still',
#  570: 'patterns',
#  571: 'eye',
#  572: 'analgesic',
#  573: 'caused',
#  574: 'containing',
#  575: 'pet',
#  576: 'free',
#  577: 'kg',
#  578: 'cocaine',
#  579: 'scn',
#  580: 'diseases',
#  581: 'fact',
#  582: 'duration',
#  583: 'report',
#  584: 'least',
#  585: 'structural',
#  586: 'schizophrenia',
#  587: 'concentrations',
#  588: 'immune',
#  589: 'molecular',
#  590: 'work',
#  591: 'interest',
#  592: 'family',
#  593: 'nitric',
#  594: 'appear',
#  595: '5-ht',
#  596: 'nrem',
#  597: 'contribute',
#  598: 'across',
#  599: 'mean',
#  600: 'delayed',
#  601: 'range',
#  602: 'distal',
#  603: 'glutamatergic',
#  604: 'left',
#  605: 'intracellular',
#  606: 'responsible',
#  607: 'neurodegenerative',
#  608: 'causes',
#  609: 'include',
#  610: 'required',
#  611: 'called',
#  612: 'induces',
#  613: 'forebrain',
#  614: 'condition',
#  615: 'noradrenergic',
#  616: 'affect',
#  617: 'cause',
#  618: 'importance',
#  619: 'degeneration',
#  620: 'seen',
#  621: 'prl',
#  622: 'ischemia',
#  623: 'line',
#  624: 'adenosine',
#  625: 'relational',
#  626: 'cycle',
#  627: 'reactive',
#  628: '—',
#  629: 'specifically',
#  630: 'second',
#  631: 'generally',
#  632: 'exposed',
#  633: 'relationships',
#  634: 'them',
#  635: 'active',
#  636: 'b',
#  637: 'effective',
#  638: 'hormones',
#  639: 'occurs',
#  640: 'signal',
#  641: 'relative',
#  642: 'muscle',
#  643: 'correlated',
#  644: 'field',
#  645: 'rapid',
#  646: 'anti',
#  647: 'multiple',
#  648: 'glucose',
#  649: 'input',
#  650: 'physical',
#  651: 'neurotransmission',
#  652: 'recovery',
#  653: 'il-1',
#  654: 'parkinson',
#  655: 'necessary',
#  656: 'main',
#  657: 'above',
#  658: 'component',
#  659: 'developing',
#  660: 'gyrus',
#  661: 'depression',
#  662: 'volume',
#  663: 'hpa',
#  664: 'modulation',
#  665: 'obtained',
#  666: 'retrieval',
#  667: 'distributed',
#  668: 'interactions',
#  669: 'strategies',
#  670: 'upon',
#  671: 'mental',
#  672: 'cerebellar',
#  673: 'mitochondrial',
#  674: 'out',
#  675: 'certain',
#  676: 'detected',
#  677: 'behaviors',
#  678: 'decreases',
#  679: 'experiment',
#  680: 'absence',
#  681: 'positive',
#  682: 'cytokines',
#  683: 'repeated',
#  684: 'underlying',
#  685: 'acetylcholine',
#  686: 'individual',
#  687: 'aβ',
#  688: 'case',
#  689: 'somatosensory',
#  690: 'angiotensin',
#  691: 'pkc',
#  692: 'revealed',
#  693: 'transgenic',
#  694: 'inflammation',
#  695: 'projections',
#  696: 'night',
#  697: 'representation',
#  698: 'exercise',
#  699: 'reduce',
#  700: 'co',
#  701: 'features',
#  702: 'established',
#  703: 'food',
#  704: 'lower',
#  705: 'activities',
#  706: 'characteristics',
#  707: 'training',
#  708: 'axis',
#  709: 'expected',
#  710: 'common',
#  711: 'amphetamine',
#  712: 'perception',
#  713: 'controls',
#  714: 'synapses',
#  715: 'nachr',
#  716: 'circadian',
#  717: 'ros',
#  718: 'mediate',
#  719: 'insomnia',
#  720: 'population',
#  721: 'assess',
#  722: 'fluid',
#  723: 'old',
#  724: 'enzyme',
#  725: 'able',
#  726: 'morphological',
#  727: 'noxious',
#  728: 'nociceptive',
#  729: 'subunit',
#  730: 'application',
#  731: 'taste',
#  732: 'nicotinic',
#  733: 'slow',
#  734: 'tests',
#  735: 'lobe',
#  736: 'decline',
#  737: 'seems',
#  738: 'layer',
#  739: 'dyskinesia',
#  740: 'subsequent',
#  741: 'calcium',
#  742: 'defined',
#  743: 'view',
#  744: 'understood',
#  745: 'heat',
#  746: 'pvn',
#  747: 'd2',
#  748: 'genetic',
#  749: 'did',
#  750: 'limbic',
#  751: 'understanding',
#  752: 'combined',
#  753: 'sex',
#  754: 'escape',
#  755: 'implicated',
#  756: 'weeks',
#  757: 'parietal',
#  758: 'elderly',
#  759: 'dream',
#  760: 'dopa',
#  761: 'granule',
#  762: 'sep',
#  763: 'oxygen',
#  764: 'severe',
#  765: 'reflect',
#  766: 'primarily',
#  767: 'relevant',
#  768: 'point',
#  769: 'developed',
#  770: 'sensitivity',
#  771: 'peptides',
#  772: 'potentiation',
#  773: 'fear',
#  774: 'local',
#  775: 'little',
#  776: 'association',
#  777: 'together',
#  778: 'analgesia',
#  779: 'ne',
#  780: 'stimulate',
#  781: 'potent',
#  782: 'evaluate',
#  783: 'face',
#  784: 'locomotor',
#  785: 'systemic',
#  786: 'target',
#  787: 'cardiovascular',
#  788: 'how',
#  789: 'npy',
#  790: 'estradiol',
#  791: 'sd',
#  792: 'aspects',
#  793: 'assessed',
#  794: 'frequently',
#  795: 'consumption',
#  796: 'nature',
#  797: 'ischemic',
#  798: 'context',
#  799: 'distinct',
#  800: 'extracellular',
#  801: 'tract',
#  802: 'attention',
#  803: 'iii',
#  804: 'total',
#  805: 'presynaptic',
#  806: 'individuals',
#  807: 'amount',
#  808: 'reflex',
#  809: 'lasting',
#  810: 'healthy',
#  811: 'acceleration',
#  812: 'additional',
#  813: 'interaction',
#  814: 'nachrs',
#  815: 'better',
#  816: 'gabaergic',
#  817: 'rhythms',
#  818: 'right',
#  819: 'taurine',
#  820: 'crucial',
#  821: 'mediating',
#  822: 'disruption',
#  823: 'inhibitor',
#  824: 'impairments',
#  825: 'social',
#  826: 'focused',
#  827: 'enzymes',
#  828: 'postnatal',
#  829: 'serotonergic',
#  830: 'abnormal',
#  831: 'much',
#  832: 'throughout',
#  833: 'therapeutic',
#  834: 'regional',
#  835: 'yet',
#  836: 'afferent',
#  837: 'enhanced',
#  838: 'gvs',
#  839: 'homeostasis',
#  840: 'latency',
#  841: 'paraventricular',
#  842: 'act',
#  843: 'difference',
#  844: 'neuroprotective',
#  845: 'techniques',
#  846: 'intake',
#  847: 'produces',
#  848: 'four',
#  849: 'indicated',
#  850: 'serotonin',
#  851: 'negative',
#  852: 'brainstem',
#  853: 'estrogen',
#  854: 'neurological',
#  855: 'sites',
#  856: 'here',
#  857: 'α-synuclein',
#  858: 'paradigm',
#  859: 'acquired',
#  860: 'extent',
#  861: 'remains',
#  862: 'vascular',
#  863: 'proliferation',
#  864: 'way',
#  865: 'set',
#  866: 'spontaneous',
#  867: 'open',
#  868: 'muscles',
#  869: 'auditory',
#  870: 'states',
#  871: 'interneurons',
#  872: 'clear',
#  873: 'risk',
#  874: 'simple',
#  875: 'identity',
#  876: 'ampa',
#  877: 'mt',
#  878: 'adults',
#  879: 'stage',
#  880: 'recognition',
#  881: 'made',
#  882: 'clearly',
#  883: 'investigation',
#  884: 'glial',
#  885: 'pig',
#  886: 'limited',
#  887: 'males',
#  888: 'autonomic',
#  889: 'maintenance',
#  890: 'transcription',
#  891: 'released',
#  892: 'determined',
#  893: 'turn',
#  894: 'progressive',
#  895: 'g',
#  896: 'periods',
#  897: 'laboratory',
#  898: 'neonatal',
#  899: 'bilateral',
#  900: 'substrate',
#  901: 'dna',
#  902: 'late',
#  903: 'recall',
#  904: 'retina',
#  905: 'additionally',
#  906: 'encoding',
#  907: 'nts',
#  908: 'arm',
#  909: 'pathogenesis',
#  910: 'methods',
#  911: 'unclear',
#  912: 'involving',
#  913: 'approximately',
#  914: 'staining',
#  915: 'inhibited',
#  916: 'gabaa',
#  917: 'roles',
#  918: 'emotional',
#  919: 'modulate',
#  920: 'toxicity',
#  921: 'event',
#  922: 'ion',
#  923: 'prenatal',
#  924: 'striatal',
#  925: 'consolidation',
#  926: 'lack',
#  927: 'balance',
#  928: 'life',
#  929: 'uptake',
#  930: 'resulting',
#  931: 'axons',
#  932: 'occurring',
#  933: 'key',
#  934: 'months',
#  935: 'elevated',
#  936: 'mediation',
#  937: 'doses',
#  938: 'coupled',
#  939: 'direction',
#  940: 'possibly',
#  941: 'therapy',
#  942: 'excitation',
#  943: 'immunoreactivity',
#  944: 'arousal',
#  945: 'end',
#  946: 'sg',
#  947: '5-ht1a',
#  948: 'clonidine',
#  949: 'gdnf',
#  950: 'sv',
#  951: 'inhibit',
#  952: 'standard',
#  953: 'self',
#  954: 'subject',
#  955: 'difficult',
#  956: 'measure',
#  957: 'accompanied',
#  958: 'preoptic',
#  959: 'surface',
#  960: 'neurotoxicity',
#  961: 'p',
#  962: 'alter',
#  963: 'believed',
#  964: 'il-1β',
#  965: 'showing',
#  966: 'whole',
#  967: 'acids',
#  968: 'metabolic',
#  969: 'preference',
#  970: 'attentional',
#  971: 'greater',
#  972: 'generated',
#  973: 'purpose',
#  974: 'regulated',
#  975: 'partial',
#  976: 'channel',
#  977: 'increasing',
#  978: 'firing',
#  979: 'reaction',
#  980: 'modified',
#  981: 'comparison',
#  982: 'cases',
#  983: 'working',
#  984: 'injections',
#  985: 'acts',
#  986: 'controlled',
#  987: 'gravity',
#  988: 'substance',
#  989: '10',
#  990: 'authors',
#  991: 'already',
#  992: 'exhibit',
#  993: 'olfactory',
#  994: 'generation',
#  995: 'erd',
#  996: 'evaluated',
#  997: 'alternative',
#  998: 'exert',
#  999: 'na',
#  1000: 'cultures',
#  ...}

# %%
for i in sequences[0]:
    print(f'{i} : {tokenizer.index_word[i]}')
# Out:
# 1 : the
# 5020 : ubiquitin
# 2162 : proteasome
# 496 : pathway
# 606 : responsible
# 13 : for
# 821 : mediating
# 1 : the
# 1638 : majority
# 2 : of
# 605 : intracellular
# 4177 : proteolysis
# 514 : plays
# 6 : a
# 820 : crucial
# 56 : role
# 3 : in
# 1 : the
# 160 : regulation
# 2 : of
# 170 : many
# 162 : normal
# 310 : cellular
# 175 : processes
# 87 : including
# 1 : the

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('the', 261844),
#              ('ubiquitin', 54),
#              ('proteasome', 237),
#              ('pathway', 1122),
#              ('responsible', 967),
#              ('for', 27462),
#              ('mediating', 735),
#              ('majority', 347),
#              ('of', 191312),
#              ('intracellular', 982),
#              ('proteolysis', 90),
#              ('plays', 1105),
#              ('a', 66548),
#              ('crucial', 743),
#              ('role', 6932),
#              ('in', 143339),
#              ('regulation', 3087),
#              ('many', 2907),
#              ('normal', 3038),
#              ('cellular', 1741),
#              ('processes', 2806),
#              ('including', 4809),
#              ('cell', 6864),
#              ('cycle', 936),
#              ('differentiation', 1118),
#              ('and', 122712),
#              ('apoptosis', 1300),
#              ('refs!!!.', 33956),
#              ('defects', 182),
#              ('function', 3614),
#              ('have', 19240),
#              ('been', 20774),
#              ('suggested', 2314),
#              ('to', 90142),
#              ('be', 19630),
#              ('involved', 4758),
#              ('pathogenesis', 650),
#              ('neurodegenerative', 962),
#              ('diseases', 988),
#              ('alzheimer', 1118),
#              ("'s", 2574),
#              ('disease', 4160),
#              ('parkinson', 910),
#              ('ref!!!.', 36296),
#              ('inhibitors', 546),
#              ('shown', 5590),
#              ('induce', 2080),
#              ('neuronal', 5928),
#              ('cells', 8008),
#              ('characterized', 1716),
#              ('by', 30212),
#              ('nuclear', 364),
#              ('fragmentation', 182),
#              ('loss', 1690),
#              ('mitochondrial', 901),
#              ('membrane', 1222),
#              ('potential', 1638),
#              ('cytochrome', 299),
#              ('release', 3860),
#              ('caspase', 78),
#              ('activation', 5694),
#              ('contrast', 1404),
#              ('lactacystin', 52),
#              ('acllnai', 52),
#              ('apoptotic', 494),
#              ('death', 2496),
#              ('human', 2938),
#              ('glioma', 52),
#              ('mitochondria', 312),
#              ('independent', 416),
#              ('mechanism', 1482),
#              ('addition', 2678),
#              ('it', 12844),
#              ('is', 46098),
#              ('uncertain', 156),
#              ('whether', 3822),
#              ('cytotoxicity', 156),
#              ('mg132', 156),
#              ('mediated', 2262),
#              ('elevation', 364),
#              ('ca2', 1594),
#              ('levels', 4531),
#              ('disruption', 728),
#              ('calcium', 806),
#              ('homeostasis', 702),
#              ('mediate', 832),
#              ('leads', 1144),
#              ('production', 1768),
#              ('reactive', 936),
#              ('oxygen', 780),
#              ('species', 1690),
#              ('ros', 836),
#              ('nitrogen', 156),
#              ('overload', 104),
#              ('may', 9490),
#              ('excessively', 104),
#              ('activate', 520),
#              ('ca2+/calmodulin', 78),
#              ('dependent', 2054),
#              ('pathways', 1508),
#              ('irreversible', 130),
#              ('damage', 2356),
#              ('calmodulin', 254),
#              ('antagonists', 1787),
#              ('such', 9126),
#              ('as', 27196),
#              ('w-7', 104),
#              ('trifluoperazine', 260),
#              ('inhibit', 624),
#              ('due', 1820),
#              ('1-methyl-4-phenylpyridinium', 52),
#              ('mpp+', 130),
#              ('or', 18408),
#              ('veratridine', 52),
#              ('induced', 8632),
#              ('depolarization', 286),
#              ('an', 16120),
#              ('inhibitor', 728),
#              ('permeability', 182),
#              ('transition', 390),
#              ('demonstrated', 3510),
#              ('reduce', 858),
#              ('oxidative', 1274),
#              ('stress', 5720),
#              ('suppressing', 130),
#              ('meanwhile', 78),
#              ('phenothiazines', 52),
#              ('show', 2496),
#              ('strong', 572),
#              ('antiproliferative', 52),
#              ('activity', 9854),
#              ('against', 1092),
#              ('leukemic', 52),
#              ('which', 13884),
#              ('effectively', 156),
#              ('blocks', 338),
#              ('proteolytic', 130),
#              ('26s', 52),
#              ('complex', 1664),
#              ('causes', 962),
#              ('through', 2548),
#              ('formation', 1852),
#              ('although', 3354),
#              ('antagonist', 2210),
#              ('injury', 1872),
#              ('effect', 6704),
#              ('on', 22924),
#              ('has', 16718),
#              ('not', 10296),
#              ('elucidated', 156),
#              ('aim', 1586),
#              ('present', 6292),
#              ('study', 10503),
#              ('was', 15366),
#              ('explore', 338),
#              ('calmidazolium', 52),
#              ('mg132-induced', 52),
#              ('dysfunction', 494),
#              ('pc12', 156),
#              ('this', 19500),
#              ('examined', 2000),
#              ('subsequent', 820),
#              ('changes', 6875),
#              ('gsh', 27),
#              ('contents', 494),
#              ('                            ', 26),
#              ('all', 3250),
#              ('sleep', 7852),
#              ('disorders', 2236),
#              ('insomnia', 832),
#              ('most', 4290),
#              ('prevalent', 52),
#              ('among', 1846),
#              ('adults', 676),
#              ('estimated', 390),
#              ('population', 832),
#              ('prevalence', 260),
#              ('difficulties', 442),
#              ('initiating', 234),
#              ('maintaining', 208),
#              ('about', 2210),
#              ('30', 312),
#              ('while', 3224),
#              ('frequent', 234),
#              ('severe', 780),
#              ('reported', 5408),
#              ('being', 1222),
#              ('closer', 78),
#              ('10–15', 52),
#              ('e.g.', 3016),
#              ('different', 6344),
#              ('estimates', 104),
#              ('reflect', 780),
#              ('fact', 988),
#              ('that', 43342),
#              ('variously', 26),
#              ('regarded', 208),
#              ('complaint', 130),
#              ('disorder', 1612),
#              ('symptom', 104),
#              ('finding', 338),
#              ('at', 7332),
#              ('researchers', 130),
#              ('consider', 156),
#              ('duration', 988),
#              ('severity', 546),
#              ('criteria', 364),
#              ('proposed', 1378),
#              ('dsm', 156),
#              ('iv', 208),
#              ('icsd', 130),
#              ('classifications', 52),
#              ('“', 3952),
#              ('standard', 624),
#              ('”', 3900),
#              ('definition', 260),
#              ('both', 7046),
#              ('assign', 52),
#              ('subjective', 364),
#              ('insufficient', 182),
#              ('inadequate', 52),
#              ('current', 1456),
#              ('clinical', 1898),
#              ('guidelines', 26),
#              ('given', 1274),
#              ('less', 1456),
#              ('emphasize', 52),
#              ('relevance', 208),
#              ('objective', 338),
#              ('data', 2704),
#              ('poligraphic', 26),
#              ('recordings', 286),
#              ('diagnosis', 182),
#              ('are', 25090),
#              ('now', 572),
#              ('primarily', 780),
#              ('based', 2366),
#              ('what', 364),
#              ('patients', 4550),
#              ('report', 988),
#              ('self', 624),
#              ('questionnaires', 156),
#              ('long', 3380),
#              ('time', 2756),
#              ('easiest', 26),
#              ('widely', 1456),
#              ('used', 5590),
#              ('method', 1144),
#              ('collecting', 78),
#              ('epidemiological', 156),
#              ('studies', 11726),
#              ('other', 6552),
#              ('impairments', 728),
#              ('structured', 78),
#              ('interviews', 52),
#              ('could', 3380),
#              ('screening', 182),
#              ('purposes', 260),
#              ('within', 3458),
#              ('early', 1716),
#              ('stage', 676),
#              ('assessment', 260),
#              ('unfortunately', 78),
#              ('however', 7072),
#              ('paper', 364),
#              ('pencil', 52),
#              ('instruments', 26),
#              ('either', 1742),
#              ('very', 1534),
#              ('do', 1170),
#              ('include', 962),
#              ('questions', 286),
#              ('necessary', 910),
#              ('according', 1170),
#              ('standards', 52),
#              ('order', 2106),
#              ('obtain', 286),
#              ('adequate', 182),
#              ('recognition', 676),
#              ('interview', 26),
#              ('questionnaire', 156),
#              ('should', 1092),
#              ('main', 910),
#              ('aspects', 754),
#              ('characterize', 286),
#              ('diagnostic', 208),
#              ('systems', 2158),
#              ('recent', 2366),
#              ('consensus', 156),
#              ('reports', 1352),
#              ('these', 13416),
#              ('symptoms', 1690),
#              ('intensity', 572),
#              ('frequency', 1742),
#              ('well', 5330),
#              ('their', 4784),
#              ('impact', 442),
#              ('daytime', 208),
#              ('functioning', 416),
#              ('with', 28470),
#              ('regards', 182),
#              ('defined', 806),
#              ('onset', 1222),
#              ('latency', 702),
#              ('more', 5148),
#              ('than', 4628),
#              ('30min', 130),
#              ('and/or', 1560),
#              ('awakenings', 442),
#              ('after', 5720),
#              ('morning', 234),
#              ('awakening', 468),
#              ('co', 858),
#              ('occurrence', 468),
#              ('three', 1950),
#              ('required', 962),
#              ('establish', 390),
#              ('presence', 1742),
#              ('problem', 572),
#              ('so', 1248),
#              ('chronic', 2756),
#              ('considered', 1508),
#              ('relevant', 780),
#              ('from', 12974),
#              ('point', 780),
#              ('view', 806),
#              ('following', 3146),
#              ('1', 1924),
#              ('disturbance', 260),
#              ('must', 416),
#              ('nights', 52),
#              ('per', 546),
#              ('week', 260),
#              ('2', 1534),
#              ('subject', 624),
#              ('refer', 78),
#              ('lasts', 78),
#              ('month', 130),
#              ('3', 1040),
#              ('state', 1508),
#              ('significant', 2314),
#              ('impairment', 1560),
#              ('her', 130),
#              ('his', 234),
#              ('social', 728),
#              ('occupational', 26),
#              ('cognitive', 3536),
#              ('surveys', 26),
#              ('far', 468),
#              ('made', 676),
#              ('aforesaid', 26),
#              ('but', 6188),
#              ('focused', 728),
#              ('few', 1014),
#              ('general', 1066),
#              ('habitual', 52),
#              ('quality', 338),
#              ('type', 2704),
#              ('recently', 2418),
#              ('computer', 156),
#              ('aided', 26),
#              ('telephone', 26),
#              ('—', 936),
#              ('cati', 52),
#              ('difficult', 624),
#              ('reconcile', 26),
#              ('systematic', 130),
#              ('scientific', 208),
#              ('soundness', 26),
#              ('methods', 650),
#              ('necessities', 26),
#              ('settings', 208),
#              ('practical', 104),
#              ('reasons', 286),
#              ('use', 2366),
#              ('brief', 520),
#              ('often', 1404),
#              ('recommended', 26),
#              ('measures', 416),
#              ('disturbances', 416),
#              ('screenings', 26),
#              ('some', 5174),
#              ('focus', 390),
#              ('specifically', 936),
#              ('consequences', 364),
#              ('index', 260),
#              ('others', 546),
#              ('dysfunctional', 104),
#              ('beliefs', 78),
#              ('attitudes', 26),
#              ('scale', 468),
#              ('assess', 832),
#              ('dissatisfaction', 26),
#              ('sdq', 156),
#              ('pittsburgh', 52),
#              ('psqi', 104),
#              ('they', 3848),
#              ('ask', 26),
#              ('evaluation', 286),
#              ('r.', 26),
#              ('validated', 78),
#              ('designed', 572),
#              ('define', 182),
#              ('features', 858),
#              ('psychometric', 26),
#              ('proprieties', 26),
#              ('extensively', 520),
#              ('evaluated', 598),
#              ('non', 4576),
#              ('groups', 1482),
#              ('subjects', 2834),
#              ('refs', 14430),
#              ('psychiatric', 286),
#              ('somatic', 182),
#              ('primary', 2002),
#              ('ground', 52),
#              ('previous', 2652),
#              ('research', 1222),
#              ('we', 12558),
#              ('developed', 780),
#              ('bounded', 26),
#              ('precise', 286),
#              ('preliminary', 286),
#              ('detection', 416),
#              ('pre', 572),
#              ('called', 962),
#              ('allows', 390),
#              ('pilot', 104),
#              ('understood', 806),
#              ('can', 9334),
#              ('completed', 156),
#              ('scored', 52),
#              ('minutes', 26),
#              ('two', 4810),
#              ('were', 10764),
#              ('carried', 182),
#              ('out', 884),
#              ('validity', 156),
#              ('measure', 624),
#              ('first', 2626),
#              ('convergent', 52),
#              ('considering', 364),
#              ('global', 416),
#              ('score', 182),
#              ('criterion', 52),
#              ('sample', 260),
#              ('waiting', 26),
#              ('care', 104),
#              ('visit', 26),
#              ('second', 936),
#              ('assessed', 754),
#              ('sensitivity', 780),
#              ('specificity', 286),
#              ('discriminating', 78),
#              ('between', 7566),
#              ('diagnosed', 26),
#              ('insomniacs', 156),
#              ('established', 858),
#              ('sleepers', 26),
#              ('extensive', 312),
#              ('college', 52),
#              ('students', 78),
#              ('homeothermic', 130),
#              ('animals', 4810),
#              ('keep', 78),
#              ('constant', 416),
#              ('body', 2288),
#              ('temperature', 1144),
#              ('heat', 806),
#              ('disrupts', 26),
#              ('control', 3406),
#              ('induces', 962),
#              ('hyperthermia', 260),
#              ('dehydration', 260),
#              ('accompanied', 624),
#              ('hyperosmolarity', 26),
#              ('hypovolemia', 52),
#              ('defensive', 208),
#              ('responses', 4030),
#              ('phenomena', 546),
#              ('clarify', 286),
#              ('integral', 78),
#              ('acting', 572),
#              ('regulations', 26),
#              ('thermoregulation', 364),
#              ('fluid', 832),
#              ('central', 4914),
#              ('nervous', 2574),
#              ('system', 6994),
#              ('especially', 1300),
#              ('hypothalamus', 2028),
#              ('important', 4212),
#              ('preoptic', 624),
#              ('area', 2756),
#              ('poa', 312),
#              ('anterior', 1378),
#              ('hypothalamic', 1612),
#              ('ah', 52),
#              ('known', 3718),
#              ('thermoregulatory', 52),
#              ('center', 130),
#              ('activates', 494),
#              ('regions', 3874),
#              ('furthermore', 2132),
#              ('warm', 26),
#              ('stimulation', 5356),
#              ('paraventricular', 702),
#              ('nucleus', 4290),
#              ('pvn', 806),
#              ('supraoptic', 286),
#              ('lateral', 1534),
#              ('lh', 1066),
#              ('also', 11960),
#              ('thermolysis', 78),
#              ('vasodilatation', 26),
#              ('medial', 1482),
#              ('forebrain', 962),
#              ('bundle', 416),
#              ('hand', 1066),
#              ('lesions', 3146),
#              ('zona', 52),
#              ('incerta', 52),
#              ('disrupt', 364),
#              ('drinking', 182),
#              ('activated', 1430),
#              ('accordingly', 364),
#              ('large', 1456),
#              ('part', 1378),
#              ('thought', 1118),
#              ('act', 702),
#              ('there', 4680),
#              ('numerous', 572),
#              ('generally', 936),
#              ('one', 5174),
#              ('condition', 962),
#              ('results', 3432),
#              ('observed', 3588),
#              ('example', 2080),
#              ('differences', 2340),
#              ('brought', 130),
#              ('conditions', 2366),
#              ('increases', 1794),
#              ('then', 1274),
#              ('vasomotor', 52),
#              ('further', 1898),
#              ('secondarily', 104),
#              ('evaporative', 52),
#              ('water', 1716),
#              ('sweating', 52),
#              ('humans', 1742),
#              ('thermal', 260),
#              ('panting', 26),
#              ('dogs', 52),
#              ('rabbits', 234),
#              ('salivation', 78),
#              ('rodents', 1170),
#              ('least', 988),
#              ('physiological', 2184),
#              ('only', 4004),
#              ('investigated', 1872),
#              ('each', 1534),
#              ('clearly', 676),
#              ('exist', 546),
#              ('because', 2470),
#              ('utilize', 52),
#              ('until', 312),
#              ('exposed', 936),
#              ('exceeds', 104),
#              ('36–40', 26),
#              ('°', 208),
#              ('c', 2860),
#              ('distinction', 104),
#              ('investigation', 676),
#              ('deprivation', 1430),
#              ('investigate', 1066),
#              ('difference', 702),
#              ('osmoregulation', 78),
#              ('questioned', 26),
#              ('same', 2314),
#              ('mice', 3692),
#              ('under', 2028),
#              ('34', 52),
#              ('38.5', 26),
#              ('attempt', 260),
#              ('distinguish', 182),
#              ('using', 3718),
#              ('immunostaining', 104),
#              ('fos', 2054),
#              ('protein', 4264),
#              ('frequently', 754),
#              ('neuroendocrinological', 52),
#              ('maker', 26),
#              ('neuron', 494),
#              ('number', 2912),
#              ('neurons', 12194),
#              ('region', 2392),
#              ('previously', 1612),
#              ('food', 858),
#              ('consumption', 754),
#              ('decreased', 1118),
#              ('above', 910),
#              ('corticosterone', 390),
#              ('cort', 104),
#              ('vasopressin', 364),
#              ('avp', 1118),
#              ('blood', 2756),
#              ('increased', 3640),
#              ('37', 26),
#              ('relationships', 936),
#              ('unclear', 650),
#              ('discussed', 260),
#              ('amyloid', 494),
#              ('precursor', 416),
#              ('app', 1092),
#              ('ubiquitously', 156),
#              ('expressed', 1924),
#              ('spanning', 104),
#              ('glycoprotein', 52),
#              ('endoproteolytically', 26),
#              ('processed', 52),
#              ('4-kda', 26),
#              ('39–43', 52),
#              ('amino', 1378),
#              ('acid', 2444),
#              ('residue', 78),
#              ('β-amyloid', 260),
#              ('peptide', 1092),
#              ('βap', 364),
#              ('major', 2028),
#              ('component', 910),
#              ('senile', 78),
#              ('plaques', 234),
#              ('’s', 1430),
#              ('ad', 1924),
#              ('route', 156),
#              ('processing', 2522),
#              ('via', 1560),
#              ('α-secretase', 26),
#              ('incompatible', 26),
#              ('amyloidogenic', 78),
#              ('metabolism', 1118),
#              ('yields', 182),
#              ('neuroprotective', 702),
#              ('soluble', 312),
#              ('form', 1352),
#              ('sappα', 26),
#              ('alternative', 598),
#              ('involving', 650),
#              ('cleavage', 52),
#              ('β-', 52),
#              ('γ-secretases', 52),
#              ('result', 1586),
#              ('neurotoxic', 364),
#              ('produced', 1742),
#              ('structural', 988),
#              ('conservation', 52),
#              ('superfamily', 156),
#              ('ubiquitous', 104),
#              ('expression', 7176),
#              ('indicate', 1222),
#              ('like', 1950),
#              ('proteins', 1794),
#              ('play', 2132),
#              ('neurite', 104),
#              ('growth', 1612),
#              ('cytokine', 416),
#              ('promotion', 130),
#              ('survival', 1092),
#              ('adhesion', 78),
#              ('surface', 624),
#              ('receptor', 9854),
#              ('specific', 3666),
#              ('ligand', 442),
#              ('binds', 234),
#              ('inserted', 52),
#              ('kinetics', 182),
#              ('identified', 1274),
#              ('support', 1274),
#              ('observation', 442),
#              ('associate', 26),
#              ('gtp', 26),
#              ('binding', 2210),
#              ('go', 234),
#              ('motif', 26),
#              ('cytoplasmic', 260),
#              ('domain', 338),
#              ('just', 234),
#              ('essential', 1144),
#              ('organism', 182),
#              ('its', 4264),
#              ('appears', 1196),
#              ('participate', 364),
#              ('astounding', 26),
#              ('yielding', 26),
#              ('freely', 416),
#              ('floating', 52),
#              ('during', 8788),
#              ('course', 494),
#              ('develop', 546),
#              ('behavioral', 2782),
#              ('dementia', 520),
#              ('bpsd', 26),
#              ('require', 546),
#              ('antipsychotic', 208),
#              ('medication', 78),
#              ('demonstrate', 572),
#              ('pathology', 364),
#              ('infrequent', 26),
#              ('schizophrenia', 988),
#              ('sch', 104),
#              ('medications', 104),
#              ('treat', 130),
#              ('might', 2002),
#              ('actually', 312),
#              ('protective', 546),
#              ('developing', 910),
#              ('neuropathology', 260),
#              ('traditional', 208),
#              ('haloperidol', 156),
#              ('hal', 130),
#              ('dopamine-2', 26),
#              ('d2', 806),
#              ('sigma-1', 26),
#              ('σ1', 26),
#              ('neurotoxicity', 624),
#              ('causing', 234),
#              ('clinically', 286),
#              ('troublesome', 26),
#              ('adverse', 390),
#              ('events', 1300),
#              ('extrapyramidal', 26),
#              ('cardiac', 234),
#              ('side', 546),
#              ('effects', 10556),
#              ('efficiently', 130),
#              ('vitro', 1352),
#              ('exert', 598),
#              ('atypical', 130),
#              ('risperidone', 26),
#              ('risp', 78),
#              ('high', 3900),
#              ('serotonine', 26),
#              ('5-ht2', 182),
#              ('noradrenergic', 962),
#              ('na', 598),
#              ('conventional', 338),
#              ('antipsychotics', 26),
#              ('no', 5512),
#              ('light', 1092),
#              ('evidence', 3536),
#              ('prescribed', 26),
#              ('treatment', 3042),
#              ('ref!!!—interferes', 26),
#              ('vivo', 1794),
#              ('regard', 208),
#              ('peripherally', 104),
#              ('steroids', 390),
#              ('circulate', 26),
#              ('bloodstream', 52),
#              ('organs', 286),
#              ('brain', 16042),
#              ('rich', 234),
#              ('supply', 312),
#              ('selective', 1716),
#              ('absorption', 26),
#              ('–', 3900),
#              ('barrier', 286),
#              ('astrocytes', 1040),
#              ('take', 234),
#              ('up', 1118),
#              ('peripheral', 1924),
#              ('metabolise', 26),
#              ('them', 936),
#              ('into', 3692),
#              ('neuroactive', 78),
#              ('relatively', 1014),
#              ('discoveries', 26),
#              ('found', 4654),
#              ('synthesised', 52),
#              ('cns', 2210),
#              ('termed', 442),
#              ('neurosteroids', 78),
#              ('independently', 234),
#              ('synthesis', 1352),
#              ('avoid', 156),
#              ('sharp', 26),
#              ('fluctuations', 52),
#              ('steroid', 260),
#              ('concentrations', 988),
#              ('boost', 26),
#              ('higher', 1378),
#              ('periphery', 234),
#              ('arrive', 26),
#              ('physiologically', 130),
#              ('active', 936),
#              ('certain', 884),
#              ('steroidogenic', 26),
#              ('enzymes', 728),
#              ('detected', 884),
#              ('thus', 3588),
#              ('lower', 858),
#              ('meaning', 130),
#              ('sensitive', 1508),
#              ('techniques', 702),
#              ('find', 546),
#              ('raised', 78),
#              ('question', 416),
#              ('over', 2028),
#              ('capable', 390),
#              ('synthesising', 26),
#              ('de', 234),
#              ('novo', 156),
#              ('progesterone', 416),
#              ('p', 624),
#              ('metabolites', 468),
#              ('tetrahydroprogesterone', 26),
#              ('thp', 52),
#              ('tetrahydrodeoxycorticosterone', 26),
#              ('thdoc', 130),
#              ('hypothesis', 1976),
#              ('tissue', 1690),
#              ('2-', 26),
#              ('3-day', 26),
#              ('old', 832),
#              ('sprague', 182),
#              ('dawley', 182),
#              ('rat', 4784),
#              ('pups', 442),
#              ('culturing', 52),
#              ('highly', 1066),
#              ('purified', 104),
#              ('purification', 52),
#              ('cultures', 598),
#              ('l', 1768),
#              ('leucine', 52),
#              ('methyl', 104),
#              ('ester', 104),
#              ('lme', 130),
#              ('eliminate', 156),
#              ('contaminating', 26),
#              ('microglia', 520),
#              ('lysosomotropic', 26),
#              ('agent', 416),
#              ('inducer', 26),
#              ('immune', 988),
#              ('b', 936),
#              ('t', 1040),
#              ('remove', 52),
#              ('damaging', 52),
#              ('monocytes', 156),
#              ('reducing', 182),
#              ('macrophage', 52),
#              ('populations', 364),
#              ('mixed', 182),
#              ('glial', 676),
#              ('increase', 4472),
#              ('purity', 26),
#              ('indicates', 390),
#              ('effective', 936),
#              ('microglial', 442),
#              ('approximately', 650),
#              ('0.5', 78),
#              ('confirmed', 416),
#              ('staining', 650),
#              ('receptors', 10764),
#              ('p450c17', 26),
#              ('inhibited', 650),
#              ('culture', 364),
#              ('hence', 416),
#              ('desirable', 52),
#              ('prior', 520),
#              ('21-hydroxylase', 130),
#              ('p450c21', 104),
#              ('product', 130),
#              ('deoxycorticosterone', 78),
#              ('doc', 52),
#              ('indirectly', 390),
#              ('converted', 104),
#              ('exported', 26),
#              ('bind', 182),
#              ('gabaa', 650),
#              ('adjacent', 130),
#              ('alter', 624),
#              ('action', 2496),
#              ('considerable', 338),
#              ('controversy', 130),
#              ('exists', 312),
#              ('nature', 754),
#              ('extra', 156),
#              ('adrenal', 546),
#              ('21-hydroxylation', 52),
#              ('whilst', 52),
#              ('enzyme', 832),
#              ('antibody', 234),
#              ('dhdoc', 26),
#              ('entering', 26),
#              ('mellon', 26),
#              ('workers', 156),
#              ('altogether', 78),
#              ('1996', 52),
#              ('cloned', 312),
#              ('separate', 182),
#              ('transcripts', 234),
#              ('21-oh-5', 52),
#              ('21-oh-6', 26),
#              ('sequenced', 52),
#              ('believed', 624),
#              ('splicing', 104),
#              ('rna', 78),
#              ('translated', 26),
#              ('southern', 52),
#              ('blotting', 78),
#              ('rt', 494),
#              ('pcr', 208),
#              ('various', 2262),
#              ('kidney', 208),
#              ('aorta', 26),
#              ('liver', 208),
#              ('cerebellum', 1092),
#              ('hippocampus', 3848),
#              ('constructs', 52),
#              ('tissues', 1248),
#              ('except', 182),
#              ('cerebrum', 52),
#              ('date', 338),
#              ('characterised', 286),
#              ('technique', 598),
#              ('likely', 1092),
#              ('low', 2184),
#              ('small', 1378),
#              ('autocrine', 78),
#              ('level', 2626),
#              ('areas', 3380),
#              ('able', 832),
#              ('nested', 26),
#              ('aimed', 364),
#              ('electrospray', 26),
#              ('mass', 182),
#              ('spectroscopy', 52),
#              ('esms', 26),
#              ('molecular', 988),
#              ('biology', 78),
#              ('determine', 1534),
#              ('if', 2626),
#              ('astrocyte', 104),
#              ('derived', 1066),
#              ('newborn', 156),
#              ('rats', 10842),
#              ('stereotaxic', 468),
#              ('instrument', 156),
#              ('atlas', 208),
#              ('coordinates', 156),
#              ('reliable', 286),
#              ('approaches', 520),
#              ('nuclei', 1482),
#              ('atlases', 26),
#              ('available', 1040),
#              ('rabbit', 104),
#              ('cat', 130),
#              ('goat', 78),
#              ('sheep', 78),
#              ('pig', 676),
#              ('monkey', 208),
#              ('substantial', 312),
#              ('provided', 598),
#              ('reveal', 338),
#              ('roles', 650),
#              ('intake', 702),
#              ('reproduction', 52),
#              ('learning', 4706),
#              ('memory', 5460),
#              ('emotional', 650),
#              ('behaviors', 884),
#              ('relation', 546),
#              ('development', 3354),
#              ('bovine', 234),
#              ('das', 26),
#              ('mcclure', 26),
#              ('sizes', 52),
#              ('skulls', 26),
#              ('heads', 26),
#              ('five', 312),
#              ('breeds', 26),
#              ('cattle', 104),
#              ('holstein', 52),
#              ('friesian', 26),
#              ('breed', 26),
#              ('presented', 520),
#              ('yoshikawa', 26),
#              ('reference', 338),
#              ('drawings', 52),
#              ('approach', 1066),
#              ('ventricle', 208),
#              ('heifers', 26),
#              ('calves', 52),
#              ('ames', 26),
#              ('et', 4056),
#              ('al', 4238),
#              ('helund', 26),
#              ('leshin', 26),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)

# %% [markdown]
# ### Convert to Numpy Matrix

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[   1, 5020, 2162, ...,  175,   87,    1],
#        [5020, 2162,  496, ...,   87,    1,   58],
#        [2162,  496,  606, ...,    1,   58,  626],
#        ...,
#        [2823,   48,   19, ...,    2,  717,    4],
#        [  48,   19,   39, ...,  717,    4,  310],
#        [  19,   39,  264, ...,    4,  310, 6635]])

# %% [markdown]
# # Creating an LSTM based model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

# %%
def create_model(vocabulary_size, seq_len):
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25, input_length=seq_len))
    model.add(LSTM(150, return_sequences=True))
    model.add(LSTM(150))
    model.add(Dense(150, activation='relu'))

    model.add(Dense(vocabulary_size, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
   
    model.summary()
    
    return model

# %% [markdown]
# ### Train / Test Split

# %%
from keras.utils import to_categorical

# %%
sequences
# Out:
# array([[   1, 5020, 2162, ...,  175,   87,    1],
#        [5020, 2162,  496, ...,   87,    1,   58],
#        [2162,  496,  606, ...,    1,   58,  626],
#        ...,
#        [2823,   48,   19, ...,    2,  717,    4],
#        [  48,   19,   39, ...,  717,    4,  310],
#        [  19,   39,  264, ...,    4,  310, 6635]])

# %%
# First 49 words
sequences[:,:-1]
# Out:
# array([[   1, 5020, 2162, ...,  310,  175,   87],
#        [5020, 2162,  496, ...,  175,   87,    1],
#        [2162,  496,  606, ...,   87,    1,   58],
#        ...,
#        [2823,   48,   19, ...,  285,    2,  717],
#        [  48,   19,   39, ...,    2,  717,    4],
#        [  19,   39,  264, ...,  717,    4,  310]])

# %%
# last Word
sequences[:,-1]
# Out:
# array([   1,   58,  626, ...,    4,  310, 6635])

# %%
X = sequences[:,:-1]

# %%
y = sequences[:,-1]

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
seq_len
# Out:
# 25

# %% [markdown]
# ### Training the Model

# %%
# define model
model = create_model(vocabulary_size+1, seq_len)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 25, 25)            277650
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 25, 150)           105600
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 150)               180600
# _________________________________________________________________
# dense_5 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dense_6 (Dense)              (None, 11106)             1677006
# =================================================================
# Total params: 2,263,506
# Trainable params: 2,263,506
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---
#
# ----

# %%
from pickle import dump,load

# %%
# fit model
model.fit(X, y, batch_size=128, epochs=150,verbose=2)
# Out:
# Epoch 1/150
#  - 141s - loss: 6.7272 - acc: 0.0967
# Epoch 2/150
#  - 140s - loss: 6.3824 - acc: 0.1184
# Epoch 3/150
#  - 141s - loss: 6.1500 - acc: 0.1363
# Epoch 4/150
#  - 140s - loss: 5.9735 - acc: 0.1491
# Epoch 5/150
#  - 140s - loss: 5.8279 - acc: 0.1573
# Epoch 6/150
#  - 140s - loss: 5.7055 - acc: 0.1629
# Epoch 7/150
#  - 140s - loss: 5.6027 - acc: 0.1677
# Epoch 8/150
#  - 139s - loss: 5.4969 - acc: 0.1730
# Epoch 9/150
#  - 139s - loss: 5.4040 - acc: 0.1774
# Epoch 10/150
#  - 141s - loss: 5.3187 - acc: 0.1815
# Epoch 11/150
#  - 140s - loss: 5.2407 - acc: 0.1866
# Epoch 12/150
#  - 139s - loss: 5.1697 - acc: 0.1902
# Epoch 13/150
#  - 139s - loss: 5.1035 - acc: 0.1943
# Epoch 14/150
#  - 139s - loss: 5.0384 - acc: 0.1976
# Epoch 15/150
#  - 140s - loss: 4.9789 - acc: 0.2013
# Epoch 16/150
#  - 139s - loss: 5.2744 - acc: 0.1809
# Epoch 17/150
#  - 139s - loss: 5.0134 - acc: 0.1963
# Epoch 18/150
#  - 139s - loss: 4.9330 - acc: 0.2017
# Epoch 19/150
#  - 140s - loss: 4.8690 - acc: 0.2062
# Epoch 20/150
#  - 142s - loss: 4.8063 - acc: 0.2108
# Epoch 21/150
#  - 142s - loss: 4.7441 - acc: 0.2144
# Epoch 22/150
#  - 143s - loss: 4.6795 - acc: 0.2179
# Epoch 23/150
#  - 146s - loss: 4.6137 - acc: 0.2216
# Epoch 24/150
#  - 151s - loss: 4.5596 - acc: 0.2254
# Epoch 25/150
#  - 152s - loss: 4.4822 - acc: 0.2303
# Epoch 26/150
#  - 156s - loss: 4.4212 - acc: 0.2335
# Epoch 27/150
#  - 160s - loss: 4.3588 - acc: 0.2379
# Epoch 28/150
#  - 165s - loss: 4.3002 - acc: 0.2421
# Epoch 29/150
#  - 172s - loss: 4.2437 - acc: 0.2450
# Epoch 30/150
#  - 176s - loss: 4.1932 - acc: 0.2498
# Epoch 31/150
#  - 182s - loss: 4.1399 - acc: 0.2542
# Epoch 32/150
#  - 186s - loss: 4.0909 - acc: 0.2576
# Epoch 33/150
#  - 193s - loss: 4.0424 - acc: 0.2623
# Epoch 34/150
#  - 199s - loss: 3.9969 - acc: 0.2663
# Epoch 35/150
#  - 205s - loss: 3.9506 - acc: 0.2707
# Epoch 36/150
#  - 212s - loss: 3.9091 - acc: 0.2742
# Epoch 37/150
#  - 218s - loss: 3.8711 - acc: 0.2784
# Epoch 38/150
#  - 225s - loss: 3.8305 - acc: 0.2820
# Epoch 39/150
#  - 232s - loss: 3.7910 - acc: 0.2861
# Epoch 40/150
#  - 237s - loss: 3.7532 - acc: 0.2902
# Epoch 41/150
#  - 243s - loss: 3.7153 - acc: 0.2925
# Epoch 42/150
#  - 249s - loss: 3.6810 - acc: 0.2980
# Epoch 43/150
#  - 255s - loss: 3.6424 - acc: 0.3018
# Epoch 44/150
#  - 261s - loss: 3.6076 - acc: 0.3064
# Epoch 45/150
#  - 265s - loss: 3.5741 - acc: 0.3084
# Epoch 46/150
#  - 271s - loss: 3.5374 - acc: 0.3133
# Epoch 47/150
#  - 276s - loss: 3.5085 - acc: 0.3171
# Epoch 48/150
#  - 281s - loss: 3.4687 - acc: 0.3227
# Epoch 49/150
#  - 284s - loss: 3.4392 - acc: 0.3265
# Epoch 50/150
#  - 290s - loss: 3.4045 - acc: 0.3304
# Epoch 51/150
#  - 295s - loss: 3.3681 - acc: 0.3349
# Epoch 52/150
#  - 300s - loss: 3.3383 - acc: 0.3395
# Epoch 53/150
#  - 303s - loss: 3.3076 - acc: 0.3427
# Epoch 54/150
#  - 307s - loss: 3.2747 - acc: 0.3466
# Epoch 55/150
#  - 311s - loss: 3.2417 - acc: 0.3508
# Epoch 56/150
#  - 316s - loss: 3.2086 - acc: 0.3559
# Epoch 57/150
#  - 319s - loss: 3.1820 - acc: 0.3584
# Epoch 58/150
#  - 323s - loss: 3.1485 - acc: 0.3640
# Epoch 59/150
#  - 326s - loss: 3.1220 - acc: 0.3670
# Epoch 60/150
#  - 331s - loss: 3.0883 - acc: 0.3722
# Epoch 61/150
#  - 333s - loss: 3.0604 - acc: 0.3754
# Epoch 62/150
#  - 337s - loss: 3.0301 - acc: 0.3798
# Epoch 63/150
#  - 340s - loss: 3.0034 - acc: 0.3832
# Epoch 64/150
#  - 343s - loss: 2.9782 - acc: 0.3877
# Epoch 65/150
#  - 347s - loss: 2.9449 - acc: 0.3920
# Epoch 66/150
#  - 350s - loss: 2.9188 - acc: 0.3969
# Epoch 67/150
#  - 353s - loss: 2.8885 - acc: 0.4012
# Epoch 68/150
#  - 355s - loss: 2.8658 - acc: 0.4037
# Epoch 69/150
#  - 358s - loss: 2.8336 - acc: 0.4094
# Epoch 70/150
#  - 361s - loss: 2.8061 - acc: 0.4133
# Epoch 71/150
#  - 363s - loss: 2.7821 - acc: 0.4170
# Epoch 72/150
#  - 365s - loss: 2.7503 - acc: 0.4223
# Epoch 73/150
#  - 367s - loss: 2.7256 - acc: 0.4265
# Epoch 74/150
#  - 370s - loss: 2.7003 - acc: 0.4288
# Epoch 75/150
#  - 372s - loss: 2.6736 - acc: 0.4344
# Epoch 76/150
#  - 373s - loss: 2.6496 - acc: 0.4375
# Epoch 77/150
#  - 376s - loss: 2.6272 - acc: 0.4398
# Epoch 78/150
#  - 378s - loss: 2.5963 - acc: 0.4470
# Epoch 79/150
#  - 380s - loss: 2.5766 - acc: 0.4509
# Epoch 80/150
#  - 382s - loss: 2.5510 - acc: 0.4541
# Epoch 81/150
#  - 383s - loss: 2.5300 - acc: 0.4562
# Epoch 82/150
#  - 386s - loss: 2.4966 - acc: 0.4620
# Epoch 83/150
#  - 387s - loss: 2.4853 - acc: 0.4647
# Epoch 84/150
#  - 390s - loss: 2.4520 - acc: 0.4700
# Epoch 85/150
#  - 391s - loss: 2.4397 - acc: 0.4713
# Epoch 86/150
#  - 393s - loss: 2.4096 - acc: 0.4764
# Epoch 87/150
#  - 395s - loss: 2.3858 - acc: 0.4809
# Epoch 88/150
#  - 397s - loss: 2.3722 - acc: 0.4821
# Epoch 89/150
#  - 399s - loss: 2.3385 - acc: 0.4885
# Epoch 90/150
#  - 401s - loss: 2.3182 - acc: 0.4924
# Epoch 91/150
#  - 403s - loss: 2.3043 - acc: 0.4942
# Epoch 92/150
#  - 404s - loss: 2.2780 - acc: 0.4990
# Epoch 93/150
#  - 406s - loss: 2.2531 - acc: 0.5024
# Epoch 94/150
#  - 408s - loss: 2.2450 - acc: 0.5048
# Epoch 95/150
#  - 410s - loss: 2.2167 - acc: 0.5091
# Epoch 96/150
#  - 410s - loss: 2.2330 - acc: 0.5054
# Epoch 97/150
#  - 414s - loss: 2.1674 - acc: 0.5189
# Epoch 98/150
#  - 415s - loss: 2.1561 - acc: 0.5200
# Epoch 99/150
#  - 416s - loss: 2.1421 - acc: 0.5218
# Epoch 100/150
#  - 418s - loss: 2.1186 - acc: 0.5269
# Epoch 101/150
#  - 420s - loss: 2.0973 - acc: 0.5313
# Epoch 102/150
#  - 421s - loss: 2.0818 - acc: 0.5345
# Epoch 103/150
#  - 423s - loss: 2.0641 - acc: 0.5361
# Epoch 104/150
#  - 426s - loss: 2.0415 - acc: 0.5408
# Epoch 105/150
#  - 427s - loss: 2.0273 - acc: 0.5439
# Epoch 106/150
#  - 428s - loss: 2.0149 - acc: 0.5451
# Epoch 107/150
#  - 431s - loss: 1.9864 - acc: 0.5515
# Epoch 108/150
#  - 433s - loss: 1.9793 - acc: 0.5507
# Epoch 109/150
#  - 434s - loss: 1.9630 - acc: 0.5556
# Epoch 110/150
#  - 437s - loss: 1.9395 - acc: 0.5598
# Epoch 111/150
#  - 438s - loss: 1.9268 - acc: 0.5623
# Epoch 112/150
#  - 439s - loss: 1.9181 - acc: 0.5625
# Epoch 113/150
#  - 442s - loss: 1.8858 - acc: 0.5705
# Epoch 114/150
#  - 443s - loss: 1.8766 - acc: 0.5703
# Epoch 115/150
#  - 444s - loss: 1.8700 - acc: 0.5718
# Epoch 116/150
#  - 446s - loss: 1.8397 - acc: 0.5784
# Epoch 117/150
#  - 447s - loss: 1.8249 - acc: 0.5802
# Epoch 118/150
#  - 448s - loss: 1.8147 - acc: 0.5826
# Epoch 119/150
#  - 450s - loss: 1.7991 - acc: 0.5852
# Epoch 120/150
#  - 451s - loss: 1.7792 - acc: 0.5889
# Epoch 121/150
#  - 452s - loss: 1.7626 - acc: 0.5927
# Epoch 122/150
#  - 456s - loss: 1.7578 - acc: 0.5934
# Epoch 123/150
#  - 455s - loss: 1.7436 - acc: 0.5952
# Epoch 124/150
#  - 456s - loss: 1.7211 - acc: 0.6010
# Epoch 125/150
#  - 456s - loss: 1.7100 - acc: 0.6019
# Epoch 126/150
#  - 458s - loss: 1.6921 - acc: 0.6052
# Epoch 127/150
#  - 459s - loss: 1.6788 - acc: 0.6085
# Epoch 128/150
#  - 460s - loss: 1.6641 - acc: 0.6122
# Epoch 129/150
#  - 460s - loss: 1.6557 - acc: 0.6122
# Epoch 130/150
#  - 460s - loss: 1.6792 - acc: 0.6056
# Epoch 131/150
#  - 463s - loss: 1.6157 - acc: 0.6221
# Epoch 132/150
#  - 463s - loss: 1.6065 - acc: 0.6235
# Epoch 133/150
#  - 463s - loss: 1.6068 - acc: 0.6213
# Epoch 134/150
#  - 464s - loss: 1.5831 - acc: 0.6271
# Epoch 135/150
#  - 465s - loss: 1.5813 - acc: 0.6274
# Epoch 136/150
#  - 467s - loss: 1.5650 - acc: 0.6304
# Epoch 137/150
#  - 468s - loss: 1.5495 - acc: 0.6340
# Epoch 138/150
#  - 468s - loss: 1.5482 - acc: 0.6324
# Epoch 139/150
#  - 469s - loss: 1.5136 - acc: 0.6413
# Epoch 140/150
#  - 469s - loss: 1.5239 - acc: 0.6374
# Epoch 141/150
#  - 470s - loss: 1.4994 - acc: 0.6427
# Epoch 142/150
#  - 470s - loss: 1.5003 - acc: 0.6425
# Epoch 143/150
#  - 471s - loss: 1.4792 - acc: 0.6473
# Epoch 144/150
#  - 472s - loss: 1.4682 - acc: 0.6488
# Epoch 145/150
#  - 472s - loss: 1.4555 - acc: 0.6517
# Epoch 146/150
#  - 473s - loss: 1.4429 - acc: 0.6545
# Epoch 147/150
#  - 474s - loss: 1.4416 - acc: 0.6542
# Epoch 148/150
#  - 474s - loss: 1.4331 - acc: 0.6572
# Epoch 149/150
#  - 475s - loss: 1.4174 - acc: 0.6593
# Epoch 150/150
#  - 476s - loss: 1.4041 - acc: 0.6622

# %%
# save the model to file
model.save('epochBIG.h5')
# save the tokenizer
dump(tokenizer, open('epochBIG', 'wb'))

# %% [markdown]
# # Generating New Text

# %%
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''
    
    # Final Output
    output_text = []
    
    # Intial Seed Sequence
    input_text = seed_text
    
    # Create num_gen_words
    for i in range(num_gen_words):
        
        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        
        # Pad sequences to our trained rate (50 words in the video)
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')
        
        # Predict Class Probabilities for each word
        pred_word_ind = model.predict_classes(pad_encoded, verbose=0)[0]
        
        # Grab word
        pred_word = tokenizer.index_word[pred_word_ind] 
        
        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word
        
        output_text.append(pred_word)
        
    # Make it look like a sentence.
    return ' '.join(output_text)

# %% [markdown]
# ### Grab a random seed sequence

# %%
text_sequences[0]
# Out:
# ['the',
#  'ubiquitin',
#  'proteasome',
#  'pathway',
#  'responsible',
#  'for',
#  'mediating',
#  'the',
#  'majority',
#  'of',
#  'intracellular',
#  'proteolysis',
#  'plays',
#  'a',
#  'crucial',
#  'role',
#  'in',
#  'the',
#  'regulation',
#  'of',
#  'many',
#  'normal',
#  'cellular',
#  'processes',
#  'including',
#  'the']

# %%
import random
random.seed(101)
random_pick = random.randint(0,len(text_sequences))

# %%
random_seed_text = text_sequences[random_pick]

# %%
random_seed_text
# Out:
# ['spontaneously',
#  'after',
#  'systemic',
#  'administration',
#  'of',
#  '3-np',
#  'in',
#  'spite',
#  'of',
#  'extensive',
#  'research',
#  'this',
#  'devastating',
#  'hereditary',
#  'disease',
#  'remains',
#  'incurable',
#  'warranting',
#  'further',
#  'studies',
#  'to',
#  'determine',
#  'the',
#  'causes',
#  'and',
#  'cure']

# %%
seed_text = ' '.join(random_seed_text[:-4])

# %%
seed_text
# Out:
# 'spontaneously after systemic administration of 3-np in spite of extensive research this devastating hereditary disease remains incurable warranting further studies to determine'

# %%
seed_text = 'In the current study we investigated whether '

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=3)
# Out:
# 'there are predominantly'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=50)
# Out:
# 'the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain and the brain'

# %% [markdown]
# ### Exploring Generated Sequence

# %%
full_text = read_file('giant_introduction.txt')

# %%
for i,word in enumerate(full_text.split()):
    if word == 'inkling':
        print(' '.join(full_text.split()[i-20:i+20]))
        print('\n')

# %% [markdown]
# # Great Job!
